# %%
from selenium import webdriver
from selenium.webdriver.support.ui import Select
import time

# %%
driver = webdriver.Chrome(chromedriver.exe)
driver.maximize_window()

# %%
driver.get("https://www.pod2you.com/")

# %%
driver.get("https://www.pod2you.com/th/product/755810/product-755810")

# %%
element=driver.find_element_by_xpath("//div[@class='form-group']//select[@class='form-control custom-select']")

drp=Select(element)
drp.select_by_visible_text("Fresh Red (฿ 350.00)")

# %%
driver.find_element_by_xpath("//button[contains(text(),'+')]").click()

# %%
driver.find_element_by_xpath("//div[@class='bottom line -top pt_25']").click()
time.sleep(5)

# %%
driver.find_element_by_xpath("//a[contains(text(),'สั่งซื้อสินค้าในตะกร้า')]").click()

# %%
driver.get("https://www.pod2you.com/th/register")

# %%
driver.find_element_by_name("firstname").send_keys("Suphanut")
driver.find_element_by_name("lastname").send_keys("Borisutsil")
driver.find_element_by_name("email").send_keys("test@testtestemail.com")
driver.find_element_by_name("cemail").send_keys("test@testtestemail.com")
driver.find_element_by_name("password").send_keys("1234678")
driver.find_element_by_name("cpassword").send_keys("1234678")
time.sleep(5)

# %%
driver.find_element_by_xpath("//div[@class='checkbox text-left mt_0 text col-xs-6 col-xs-offset-4']//label[@for='privacyPolicy' and contains(text(),'ฉันยอมรับ')]").click()
time.sleep(5)

# %%
driver.find_element_by_xpath("//button[contains(text(),'สร้างบัญชีใหม่')]").click()
